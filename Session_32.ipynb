# %%
str1='virat.kohli@recb.com'
str2='rohit.sharma@mi.com'
str3='ms.dhoni@csk.com'
# extract the firstname from str1: virat 
# extract second name from str1:kolhi
# extract the second name from str1: rcb 
str4='a.b@c.com'

# Idea : try to get the trigger points 
str1='hello how'
str1[0:5]
# Step-1: First extract .index 
# Step-2: extract the @ index
# Step-3: extract the second . dor index
# Out:
# 'hello'

# %%
str1='hello how'
id=str1.

# %%
str1='virat.kohli@rcb.com'
first_dot=str1.index('.')
print(first_dot)
##################################
second_dot=str1.index('.')
second_name=str1[:second_dot]
print(second_name)
last_name=str1.index('@')
last_name=str1[:last_name]
print(last_name)
# Out:
# 5
# virat
# virat.kohli

# %%
str1='virat.kohli@rcb.com'
first_dot=str1.index('.')
print(first_dot)
first_name=str1[:first_dot]
print(first_name)
#############################
str2='rohit.sharma@mi.com'
first_dot=str2.index('.')
first_name
# Out:
# 5
# virat
# 'virat'

# %%
'virat.kohli@rcb.com'
def extract(str1):
    first_dot=str1.index('.')
    second_dot=str1.index('.',first_dot+1)
    at_the_rate=str1.index('@')
    print(first_dot,second_dot,at_the_rate)
    first_name=str1[:first_dot]
    second_name=str1[first_dot+1:at_the_rate]
    cname=str1[at_the_rate+1:second_dot]
    print(first_name,second_name,cname)
extract('a.b@c.com')
# Out:
# 1 5 3
# a b c

# %% [markdown]
# **Split**

# %% [markdown]
# - split is use to convert a string to list of elements
# - by default it will split based on space

# %%
str1='hai how are you'
str1.split()
# Out:
# ['hai', 'how', 'are', 'you']

# %%
str1='hai how,are you'
str1.split(',')
# Out:
# ['hai how', 'are you']

# %%
str1='hai how,are you'
str1.split()
# Out:
# ['hai', 'how,are', 'you']

# %%
str1='hello hai how,are you'
str1.split('o')
# 'hello','hai h', 'w are y', 'u'
# Out:
# ['hell', ' hai h', 'w,are y', 'u']

# %% [markdown]
# **Join**

# %%
str1='hai how are you'
l=str1.split() # how it is spillted = ''
l
' '.join('****')
print(l)
# Out:
# ['hai', 'how', 'are', 'you']

# %%
str1='hai how,are you'
l=str1.split(',')
l
','.join(l)
# Out:
# 'hai how,are you'

# %%
str1='hello hai how are you'
l=str1.split('o')
l
'a'.join(l)
# Out:
# 'hella hai haw are yau'

# %%
- upper/lower/casefold
- title/capitalise
- center
- lstrip/rstrip/strip
- startswith/endswith
- replace
- count 
- index/find
- split/join

# %%
dir('')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
 'isalnum',
 'isalpha',
 'isascii',
 'isdecimal',
 'isdigit',
 'isidentifier',
 'islower',
 'isnumeric',
 'isprintable',
 'isspace',
 'istitle',
 'isupper',

# %%
str1='naresh'
str1.isupper(),str1.islower()
# Out:
# (False, True)
