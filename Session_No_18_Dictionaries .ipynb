# %%
names =['Ramesh','Suresh','Satish']
age=[20,25,30]
# 'Ramesh age is 20'
# 'Suresh age is 25'

# %%
for i in range(len(names)):
    print(f"{names[i]} age is {age[i]}")
# Out:
# Ramesh age is 20
# Suresh age is 25
# Satish age is 30

# %% [markdown]
# **zip**

# %%
names =['Ramesh','Suresh','Satish']
age=[20,25,30]
for i,j in zip(names,age):
    # print(i,j)
    print(f"{i} age is {j}")
# Out:
# Ramesh age is 20
# Suresh age is 25
# Satish age is 30

# %%
names =['Ramesh','Suresh','Satish']
age=[20,25,30]
for i in zip(names,age):
    print(i,j)
    print(f"{i} age is {j}")
# Out:
# ('Ramesh', 20) 30
# ('Ramesh', 20) age is 30
# ('Suresh', 25) 30
# ('Suresh', 25) age is 30
# ('Satish', 30) 30
# ('Satish', 30) age is 30

# %%
[f"{i},{j}" for i,j in zip(names,age)]
# Out:
# ['Ramesh,20', 'Suresh,25', 'Satish,30']

# %%
names =['Ramesh','Suresh','Satish']
age=[20,25,30]

# %% [markdown]
# ## Dictionary

# %% [markdown]
# - in above example names and age both are together
# - when both are together we can pair them
# - this can happned using dictionary
# - dictionary is called **key-value** pair
# - it represent with curly braces: **{key:value}**
# - Ramesh and 20 years both are paint:{'Ramesh':20}

# %%
d1={'Ramesh':20,'Suresh':25,'Satish':30}
d1
# Out:
# {'Ramesh': 20, 'Suresh': 25, 'Satish': 30}

# %%
d2={20:'Ramesh',25:'Suresh',30:'Satish'}
d2
# Out:
# {20: 'Ramesh', 25: 'Suresh', 30: 'Satish'}

# %%
# Start your imagination make a dictionary with many ways

# %%
d1={'Ramesh':20,'Suresh':25,'Satish':30}
d2={20:'Ramesh',25:'Suresh',30:'Satish'}
d3={'20':'Ramesh','25':'Suresh','30':'Satish'}
d4={'Ramesh':'20','Suresh':'25','Satish':'30'}
d5={'Ramesh':20,'Ramesh':30}
# if both case are same it will take the latest value 
# Dictionaris kind database 
d6={'Ramesh':20,'Ramesh':20}
d6
# Dictionaries does not allow duplicates 
d7={'Ramesh':20,'Suresh':20}
# In dictionary keys plays vital role
# keys can not be duplicate but values can be dduplicate 
d8= {20:'Ramesh',20:'Suresh'}
d9={True:'true'}
d10={'fruits':['Apple','Banana']}
d11={['Apple','Banana']}
d12={'fruits':('Apple','Banana')}

# %% [markdown]
# **list as keys fails because list has a mutable behaviour**
# **tuple as keys works because tuple has immutable behaviour**
# **in dictionary keys are very very important**
# **keys does not change so when we apply list is failin**

# %% [markdown]
# - if both keys are same it will take the latest value
# - Dictionarys does allows duplicats
# - in dictionary keys plays vital roles
# - keys can not be duplicaes but values can be duplicate

# %%
d14={'Fruits:'{'Apple':20}} # works
d15={{'Apple':20}:'Fruits'} # Fails

# %%
dict1={'Apple':20,'Banana:':30,'Cherry':50}
dict2={'Apple':20,'apple':30}
dict3={20:'Apple',30:'Banana',50:'Cherry'}
# apply min max sum sorted reversed

# %%
dict1={'Apple':20,'Banana:':30,'Cherry':50}
max(dict1)
dict2={'Apple':20,'apple':30}
max(dict2)
dict3={20:'Apple',30:'Banana',50:'Cherry','Banana:':30}
max(dict3)
# []
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 max(dict2)
#       5 dict3={20:'Apple',30:'Banana',50:'Cherry','Banana:':30}
# ----> 6 max(dict3)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
dict1={'Apple':20,'Banana:':30,'Cherry':50}
dict2={'Apple':20,'apple':30}
dict3={20:'Apple',30:'Banana',50:'Cherry'}
min(dict1),min(dict2),min(dict3)
# Out:
# ('Apple', 'Apple', 20)

# %%
list(reversed(dict1))
# Out:
# ['Cherry', 'Banana:', 'Apple']

# %%
sorted(dict1)
# Out:
# ['Apple', 'Banana:', 'Cherry']

# %%
len(dict1)
# Out:
# 3

# %%
dict1={'Apple':20,'Banana:':30,'Cherry':50}
'Apple' in dict1 # True 
20 in dict1 # False 
#'Apple':20 in dict1 # Error
# Out:
# False

# %%
dict1={'Apple':20,'Banana':30,'Cherry':50}

# %%
for i in dict1:
    print(i)
# Out:
# Apple
# Banana
# Cherry

# %% [markdown]
# **index**

# %%
l1=[10,20,30]
l1[0]
# Out:
# 10

# %%
str1='python'
str1[0]
# Out:
# 'p'

# %%
dict1={'Apple':20,'Banana:':30,'Cherry':50}
dict1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 dict1={'Apple':20,'Banana:':30,'Cherry':50}
# ----> 2 dict1[0]
#
# KeyError: 0

# %% [markdown]
# **how to exact the values**
# - in dictionary we have a concepts key:values pair
# - keys are very important
# - in order to get the values we need to take keys help

# %%
dict1={'Apple':20,'Banana':30,'Cherry':50}
dict1['Apple']
# Out:
# 20

# %%
dict1['Banana']
# Out:
# 30

# %%
dict1['Cherry']
# Out:
# 50

# %%
for i in dict1:
    print(i,dict1[i])
# Out:
# Apple 20
# Banana 30
# Cherry 50

# %%
# names = ['Ramesh','Suresh','Satish']
# age=[20,20,30]
names= {'Ramesh':20,'Suresh':25,'Satish':30}

# %%
print(f"Ramesh age is ",names['Ramesh'])
# Out:
# Ramesh age is  20

# %%
for key in names:
    value=names[key]
    print(f'{key} age is {value}')
# Out:
# Ramesh age is 20
# Suresh age is 25
# Satish age is 30

# %%
d={'Fruits':['Apple','Banana','Cherry']}
# get cherry

# %%
d['Fruits'][2]
# Out:
# 'Cherry'

# %%
d={'Fruits':{'Apple':['sweet','sour','green']}}

# %%
d
# Out:
# {'Fruits': {'Apple': ['sweet', 'sour', 'green']}}

# %%
d['Fruits']
d['Fruits']['Apple']
d['Fruits']['Apple'][2]
# Out:
# 'green'

# %%
d={'Fruits':[{'Cost':[50]}]}
d
# Out:
# {'Fruits': [{'Cost': [50]}]}

# %%
d['Fruits'][0]['Cost']
d['Fruits'] # list
d['Fruits'][0] # dist
d['Fruits'][0]['Cost'] # list
d['Fruits'][0]['Cost'][0]
# Out:
# 50

# %%
d={'Fruits':['Apple'],'Cost':[{'1kg':[20,30,40],'2kg':None}]}

# %%
d
# Out:
# {'Fruits': ['Apple'], 'Cost': [{'1kg': [20, 30, 40], '2kg': None}]}

# %%
d['Fruits']
d['Cost']
# Out:
# [{'1kg': [20, 30, 40], '2kg': None}]

# %%
len(d)
# Out:
# 2

# %%
len(d)
# Out:
# 2

# %%
len(d)
len(d['Cost'])
d['Cost'][0]['2kg']
d
# Out:
# {'Fruits': ['Apple'], 'Cost': [{'1kg': [20, 30, 40], '2kg': None}]}

# %%
d['Cost'][0]['2kg']

# %%
d={'Fruits':{'Orange':{'Nagpur':{'MH':{'Shivaji':{'Sambhaji'}}}}}}
d
# Out:
# {'Fruits': {'Orange': {'Nagpur': {'MH': {'Shivaji': {'Sambhaji'}}}}}}

# %%
d['Fruits']['Orange']['Nagpur']['MH']['Shivaji']
# Out:
# {'Sambhaji'}

# %% [markdown]
# **how to create an empty dictionary**
# - now onwords focus on creation of empty list ,string and dictionaries
# - we will take empty list will use append operation
# - we will take empty string will use concatenation
# - we will take empty dictionary will use key:value pair concepts

# %%
# List 
l=[]
l.append(10)
l.append(20)
l
# Out:
# [10, 20]

# %%
# Strings 
s=''
s=s+'p' # '' + 'p'
s=s+'y'# 'p' + 'y'='y'
s
# Out:
# 'py'

# %%
# dictionary 
d={}
d['Ramesh']=20
d['Suresh']=30
d['Satish']=40
d
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}

# %%
d={}
d['Ramesh']=20
d['Suresh']=30
d['Satish']=40
# d[key]=value
# d[i]=[j]

# %% [markdown]
# **How to Convert List to dictionary**

# %%
names=['Ramesh','Suresh','Satish']
age=[20,30,40]

# %%
names=['Ramesh','Suresh','Satish']
age=[20,30,40]
dict1={}
for i ,j in zip(names,age):
    print(i,j)
    dict1[i]=j
dict1
# Out:
# Ramesh 20
# Suresh 30
# Satish 40
# {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}

# %%
names=['Ramesh','Suresh','Satish']
age=[20,30,40] # j

# %% [markdown]
# **dictionary Conprehension**
# - for list comprehension we written everything inside list
# - for dict comprehension we should write everything inside dictionary

# %%
# list comprehension :[<output><forloop>]
# dict comprehension :{key:value<forloop>}

# %%
names=['Ramesh','Suresh','Satish']
age=[20,25,30]
# {i,j for i,j in zip(names,age)}

# %% [markdown]
# **mutable-immutable**
# - lists are mutable
# - dictionaries are also mutable
# - strings immutable
# - tuple mutable
# - in dictionaries wee can change values using keys

# %%
d={'Ramesh':20,'Suresh':25,'Satish':30}
d['Ramesh']=30
d
# Out:
# {'Ramesh': 30, 'Suresh': 25, 'Satish': 30}

# %% [markdown]
# **methods**

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# - clear
# - copy
# - keys
# - values
# - items

# %% [markdown]
# **Keys**

# %%
d={'Ramesh':20,'suresh':25,'Satish':30}
keys=d.keys()
keys
# Out:
# dict_keys(['Ramesh', 'suresh', 'Satish'])

# %%
type(keys)
# Out:
# dict_keys

# %%
# i got mistakes in assuming this is list type
keys.count('Ramesh')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 2
#       1 # i got mistakes in assuming this is list type
# ----> 2 keys.count('Ramesh')
#
# AttributeError: 'dict_keys' object has no attribute 'count'

# %% [markdown]
# **Convert dictionary to list **
# - in order to convert dictionaries to list
# - first we need to separate keys and values
# - then apply list type casting

# %%
d={'Ramesh':20,'suresh':25,'Satish':30}
keys=d.keys()
keys_list=list(keys)
keys_list
# Out:
# ['Ramesh', 'suresh', 'Satish']
